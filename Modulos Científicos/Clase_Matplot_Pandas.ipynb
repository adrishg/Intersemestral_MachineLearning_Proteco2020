# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0.,11.,1)
y_lineal= x
y_cuadrada= x**2
plt.plot(x,y_lineal, '+r', label='Lineal', markersize=5)
plt.plot(x,y_cuadrada, '--g', label="Cuadrada", linewidth=7)
plt.title('Gráfica lineal')
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.legend()
plt.grid(True)
plt.show()

# %%
x=np.arange(0.,10., 0.2)
seno=np.sin(x)
coseno=np.cos(x)

plt.plot(x,seno, label="Seno")
plt.plot(x,coseno, label="Coseno")
plt.title('Trigonométricas')

plt.legend()
plt.grid(True)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot()

lineas=np.arange(0,11,1)

ax.set_xticks(lineas)
ax.set_yticks(lineas)
ax.grid(True, which='both')
plt.show()

# %%
monedas = {'unPeso':8, 'dosPesos':3, 'cincoPesos':6, 'diezPesos':2}
nombreMonedas= list(monedas.keys())
numeroMonedas=list(monedas.values())

# %%
plt.bar(nombreMonedas, numeroMonedas, color='cyan', edgecolor='black', linewidth='5')
plt.title('Monedas (barras)')
plt.show()

# %%
plt.scatter(nombreMonedas, numeroMonedas, s=15,color='green', marker='o')
plt.title('Monedas (Dispersion)')
plt.show()

# %%
plt.pie(numeroMonedas, labels=nombreMonedas, colors=['blue','cyan','yellow','green'], autopct='%.4f%%', startangle=90)
plt.title('Monedas (pastel)')
plt.show()

# %%
N=50
x=np.random.rand(N)
y=np.random.rand(N)
colors = np.random.rand(N)
area = (30*np.random.rand(N))**2

plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
figura, (grafica1, grafica2)= plt.subplots(1,2, sharey=True, figsize=(10,4))
grafica1.bar(nombreMonedas, numeroMonedas)
grafica2.scatter(nombreMonedas, numeroMonedas)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig= plt.figure()
ax=Axes3D(fig)

N=100
x = np.random.rand(N)
y = np.random.rand(N)
z = np.random.rand(N)

ax.scatter(x,y,z, color='red')
ax.set_xlabel('Eje x')
ax.set_ylabel('Eje y')
ax.set_zlabel('Eje z')
plt.show()

# %%
def z(x,y):
  return np.cos(np.sqrt(x**2+y**2))

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax=Axes3D(fig)

x= np.linspace(-4,4,50)
y= np.linspace(-4,4,50)
X,Y=np.meshgrid(x,y)

ax.plot_surface(X,Y,z(X,Y), color='green')
plt.show()

# %%
import pandas as pd

# %%
s= pd.Series()
print(s)
# Out:
# Series([], dtype: float64)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
saludo= np.array(['hola','cómo', 'estan'])
s=pd.Series(saludo, index=[100,101,102])
print(s)
# Out:
# 100     hola
# 101     cómo
# 102    estan
# dtype: object

# %%
diccionario = {'h':1, 'o':2, 'l':3, 'a':4}
s=pd.Series(diccionario)
print(s)
# Out:
# h    1
# o    2
# l    3
# a    4
# dtype: int64

# %%
x=np.array([1,2,3,4])
y=pd.Series([1,2,3,4])

plt.plot(x,y)
plt.show()

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
numeros= [1,2,3,4]
df=pd.DataFrame(numeros)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
personas = [['Juan',21],['Adri', 21],['Alejandro',20]]
df=pd.DataFrame(personas)
print(df)
# Out:
#            0   1
# 0       Juan  21
# 1       Adri  21
# 2  Alejandro  20

# %%
personas = {'Nombres':['Juan','Adri','Alejandro'], 'Edades':[21,21,20]}
df=pd.DataFrame(personas)
print(df)
# Out:
#      Nombres  Edades
# 0       Juan      21
# 1       Adri      21
# 2  Alejandro      20

# %%
series={'Columna1': pd.Series([1,2,3,4]), 'Columna2':pd.Series(['a','b', 'c','d']),'Columna3':pd.Series([True,False, False,True])}
df=pd.DataFrame(series)
print(df)
# Out:
#    Columna1 Columna2  Columna3
# 0         1        a      True
# 1         2        b     False
# 2         3        c     False
# 3         4        d      True

# %%
print(df['Columna1'])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: Columna1, dtype: int64

# %%
print(df.iloc[0])
# Out:
# Columna1       1
# Columna2       a
# Columna3    True
# Name: 0, dtype: object

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# ...

# %%
df=pd.read_excel('gdrive/My Drive/Boston_Housing.xls')
boston = pd.DataFrame(df)
boston.head()

# %%
csv=pd.read_csv('https://raw.githubusercontent.com/adrishg/Intersemestral_MachineLearning_Proteco2020/master/DataSets/startupsUSA.csv')
dataFrame= pd.DataFrame(csv)
dataFrame.head()

# %%
plt.scatter(boston['RM'],boston['MEDV'])
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig= plt.figure()
ax=Axes3D(fig)

ax.scatter(boston['RM'],boston['MEDV'],boston['TAX'])
plt.show()
